# %% [markdown]
# ## Load testing scenarios.
#
# - Create multiple users with individual API keys
# - Random mapping of users to meetings
# - Bot lifecycle management
# - Background monitoring with timestamps
# - Pandas integration for data analysis

# %%
# !pip install pandas
# !pip install vexa-client --upgrade

# %%
# Import required libraries
import os
import sys
import pandas as pd
from IPython.display import clear_output, display
import time

# Add the new_tests directory to the path
sys.path.append('../testing')

# Import our test library
from load import TestSuite
from vexa_client.vexa import parse_url


from dotenv import load_dotenv
load_dotenv()

BASE_URL=os.getenv('BASE_URL')
ADMIN_API_TOKEN = os.getenv('ADMIN_API_TOKEN')
TEST_USER_API_KEY = os.getenv('TEST_USER_API_KEY')

print(BASE_URL)
# Out:
# http://localhost:18056

# %%
# Test parameters
NUM_USERS = 6
MEETING_URLS = [
    "https://meet.google.com/wmf-qsxs-wgk",

]

# %%
# Initialize TestSuite
test_suite = TestSuite(
    base_url=BASE_URL,
    admin_api_key=ADMIN_API_TOKEN,
    
)

print("TestSuite initialized")
# Out:
# TestSuite initialized

# %%
# Step 1: Create users
test_suite.cleanup()
users = test_suite.create_users(NUM_USERS)
print(f"Created {len(users)} users")
# Step 2: Create random user-meeting mapping
mapping = test_suite.create_random_mapping(MEETING_URLS)
bots = test_suite.create_bots(bot_name_prefix="DemoBot")
results = test_suite.start_all_bots(language='en', task='transcribe')
#test_suite.start_monitoring()
# Out:
# Cleaning up TestSuite...
# TestSuite cleanup completed
# Creating 6 users...
#
# DEBUG: Making POST request to http://localhost:18056/admin/users
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: {'email': 'test_user_0_8148@example.com', 'name': 'Test User 0', 'max_concurrent_bots': 2}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '164', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"test_user_0_8148@example.com","name":"Test User 0","image_url":null,"max_concurrent_bots":2,"data":{},"id":1607,"created_at":"2025-11-27T20:37:28.801714"}...
#
# DEBUG: Making POST request to http://localhost:18056/admin/users/1607/tokens
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '119', 'content-type': 'application/json'}
# DEBUG: Response content: {"user_id":1607,"id":1657,"token":"vFeLut5sziEy48On8MBFRtY7AxMMIcZRwDHeJs82","created_at":"2025-11-27T20:37:28.813415"}...
# Created user 1/6: test_user_0_8148@example.com
#
# DEBUG: Making POST request to http://localhost:18056/admin/users
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: {'email': 'test_user_1_3323@example.com', 'name': 'Test User 1', 'max_concurrent_bots': 2}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '164', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"test_user_1_3323@example.com","name":"Test User 1","image_url":null,"max_concurrent_bots":2,"data":{},"id":1608,"created_at":"2025-11-27T20:37:28.822509"}...
#
# DEBUG: Making POST request to http://localhost:18056/admin/users/1608/tokens
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '119', 'content-type': 'application/json'}
# DEBUG: Response content: {"user_id":1608,"id":1658,"token":"eoBb9qc8goPwPOwDrqFlz3hnuNVkutmte0tgcFwN","created_at":"2025-11-27T20:37:28.831369"}...
# Created user 2/6: test_user_1_3323@example.com
#
# DEBUG: Making POST request to http://localhost:18056/admin/users
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: {'email': 'test_user_2_1831@example.com', 'name': 'Test User 2', 'max_concurrent_bots': 2}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '164', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"test_user_2_1831@example.com","name":"Test User 2","image_url":null,"max_concurrent_bots":2,"data":{},"id":1609,"created_at":"2025-11-27T20:37:28.840031"}...
#
# DEBUG: Making POST request to http://localhost:18056/admin/users/1609/tokens
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '119', 'content-type': 'application/json'}
# DEBUG: Response content: {"user_id":1609,"id":1659,"token":"Tm4mmqzZex2HUaLP0F9aNGC4b4WkfqLu0T5k696t","created_at":"2025-11-27T20:37:28.848704"}...
# Created user 3/6: test_user_2_1831@example.com
#
# DEBUG: Making POST request to http://localhost:18056/admin/users
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: {'email': 'test_user_3_1205@example.com', 'name': 'Test User 3', 'max_concurrent_bots': 2}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '164', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"test_user_3_1205@example.com","name":"Test User 3","image_url":null,"max_concurrent_bots":2,"data":{},"id":1610,"created_at":"2025-11-27T20:37:28.857292"}...
#
# DEBUG: Making POST request to http://localhost:18056/admin/users/1610/tokens
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '119', 'content-type': 'application/json'}
# DEBUG: Response content: {"user_id":1610,"id":1660,"token":"s9oqulGOMMnfWI6ELOPQidFL5tiR6sTBWUfqcaAq","created_at":"2025-11-27T20:37:28.867338"}...
# Created user 4/6: test_user_3_1205@example.com
#
# DEBUG: Making POST request to http://localhost:18056/admin/users
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: {'email': 'test_user_4_1486@example.com', 'name': 'Test User 4', 'max_concurrent_bots': 2}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '164', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"test_user_4_1486@example.com","name":"Test User 4","image_url":null,"max_concurrent_bots":2,"data":{},"id":1611,"created_at":"2025-11-27T20:37:28.876495"}...
#
# DEBUG: Making POST request to http://localhost:18056/admin/users/1611/tokens
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '119', 'content-type': 'application/json'}
# DEBUG: Response content: {"user_id":1611,"id":1661,"token":"FxpBk7SMOv3vIpxTUgvkZIthigtbw4lpWVT0LWyL","created_at":"2025-11-27T20:37:28.884969"}...
# Created user 5/6: test_user_4_1486@example.com
#
# DEBUG: Making POST request to http://localhost:18056/admin/users
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: {'email': 'test_user_5_8490@example.com', 'name': 'Test User 5', 'max_concurrent_bots': 2}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '164', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"test_user_5_8490@example.com","name":"Test User 5","image_url":null,"max_concurrent_bots":2,"data":{},"id":1612,"created_at":"2025-11-27T20:37:28.893350"}...
#
# DEBUG: Making POST request to http://localhost:18056/admin/users/1612/tokens
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '119', 'content-type': 'application/json'}
# DEBUG: Response content: {"user_id":1612,"id":1662,"token":"gLHN6iijs1mu0XdKYTu1HPy2ce6dpXojQ4qOgJWX","created_at":"2025-11-27T20:37:28.901820"}...
# Created user 6/6: test_user_5_8490@example.com
# Successfully created 6 users
# Created 6 users
# Creating random mapping for 6 users and 1 meetings...
# Created mapping: {0: 'https://meet.google.com/wmf-qsxs-wgk', 1: 'https://meet.google.com/wmf-qsxs-wgk', 2: 'https://meet.google.com/wmf-qsxs-wgk', 3: 'https://meet.google.com/wmf-qsxs-wgk', 4: 'https://meet.google.com/wmf-qsxs-wgk', 5: 'https://meet.google.com/wmf-qsxs-wgk'}
# Creating 6 bots...
# Created bot DemoBot_0 for user 0 -> https://meet.google.com/wmf-qsxs-wgk
# Created bot DemoBot_1 for user 1 -> https://meet.google.com/wmf-qsxs-wgk
# Created bot DemoBot_2 for user 2 -> https://meet.google.com/wmf-qsxs-wgk
# Created bot DemoBot_3 for user 3 -> https://meet.google.com/wmf-qsxs-wgk
# Created bot DemoBot_4 for user 4 -> https://meet.google.com/wmf-qsxs-wgk
# Created bot DemoBot_5 for user 5 -> https://meet.google.com/wmf-qsxs-wgk
# Successfully created 6 bots
# Starting 6 bots using 5 threads...
# Started bot DemoBot_0
# Started bot DemoBot_1
# Started bot DemoBot_2
# Started bot DemoBot_3
# Started bot DemoBot_4
#
# DEBUG: Making POST request to http://localhost:18056/bots
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'eoBb9qc8goPwPOwDrqFlz3hnuNVkutmte0tgcFwN'}
# DEBUG: Params: None
# DEBUG: JSON data: {'platform': 'google_meet', 'native_meeting_id': 'wmf-qsxs-wgk', 'bot_name': 'Vexa-DemoBot_1', 'language': 'en', 'task': 'transcribe'}
#
# DEBUG: Making POST request to http://localhost:18056/bots
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 's9oqulGOMMnfWI6ELOPQidFL5tiR6sTBWUfqcaAq'}
# DEBUG: Params: None
# DEBUG: JSON data: {'platform': 'google_meet', 'native_meeting_id': 'wmf-qsxs-wgk', 'bot_name': 'Vexa-DemoBot_3', 'language': 'en', 'task': 'transcribe'}
#
# DEBUG: Making POST request to http://localhost:18056/bots
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'vFeLut5sziEy48On8MBFRtY7AxMMIcZRwDHeJs82'}
# DEBUG: Params: None
# DEBUG: JSON data: {'platform': 'google_meet', 'native_meeting_id': 'wmf-qsxs-wgk', 'bot_name': 'Vexa-DemoBot_0', 'language': 'en', 'task': 'transcribe'}
#
# DEBUG: Making POST request to http://localhost:18056/bots
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'FxpBk7SMOv3vIpxTUgvkZIthigtbw4lpWVT0LWyL'}
# DEBUG: Params: None
# DEBUG: JSON data: {'platform': 'google_meet', 'native_meeting_id': 'wmf-qsxs-wgk', 'bot_name': 'Vexa-DemoBot_4', 'language': 'en', 'task': 'transcribe'}
#
# DEBUG: Making POST request to http://localhost:18056/bots
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'Tm4mmqzZex2HUaLP0F9aNGC4b4WkfqLu0T5k696t'}
# DEBUG: Params: None
# DEBUG: JSON data: {'platform': 'google_meet', 'native_meeting_id': 'wmf-qsxs-wgk', 'bot_name': 'Vexa-DemoBot_2', 'language': 'en', 'task': 'transcribe'}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:28 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '386', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1912,"user_id":1608,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"requested","bot_container_id":"f342d976cf22ac749d2cb616019b6d9686ca5895d6d22a04114fd3ae5873d025","start_time":null,"end_time":null,"data":{},"created_at":"2025-11-27T20:37:28.921834","updated_at":"2025-11-27T20:37:28.940248"}...
# Started bot DemoBot_5
#
# DEBUG: Making POST request to http://localhost:18056/bots
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'gLHN6iijs1mu0XdKYTu1HPy2ce6dpXojQ4qOgJWX'}
# DEBUG: Params: None
# DEBUG: JSON data: {'platform': 'google_meet', 'native_meeting_id': 'wmf-qsxs-wgk', 'bot_name': 'Vexa-DemoBot_5', 'language': 'en', 'task': 'transcribe'}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:28 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '386', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1913,"user_id":1610,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"requested","bot_container_id":"2af95dad184cb9d06a342ce5d2a19651e17eb65b3f728f527e4c61b2757516bd","start_time":null,"end_time":null,"data":{},"created_at":"2025-11-27T20:37:28.923595","updated_at":"2025-11-27T20:37:29.047602"}...
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:28 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '386', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1914,"user_id":1611,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"requested","bot_container_id":"de0dcdfd0c18f173af1296d265d45df2ab401f2719c43d689e3f7d3b0f0d28fa","start_time":null,"end_time":null,"data":{},"created_at":"2025-11-27T20:37:29.048624","updated_at":"2025-11-27T20:37:29.602579"}...
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:28 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '386', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1916,"user_id":1609,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"requested","bot_container_id":"fcbd50d912cf58c8f2d9f4a195a2f51997d7c3669fd176d95ba6ab5677b71ae6","start_time":null,"end_time":null,"data":{},"created_at":"2025-11-27T20:37:29.048607","updated_at":"2025-11-27T20:37:29.604047"}...
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:28 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '386', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1917,"user_id":1612,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"requested","bot_container_id":"1ce91ad7780c0b9f8969fe5990d0cd8f9710ba0b8be95cbbdd391f368a2a3946","start_time":null,"end_time":null,"data":{},"created_at":"2025-11-27T20:37:29.594976","updated_at":"2025-11-27T20:37:29.604037"}...
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:37:28 GMT, Thu, 27 Nov 2025 20:37:28 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '386', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1915,"user_id":1607,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"requested","bot_container_id":"e30a307d7a3ecd58b5968423bc34c6a561d11a70fc0e021f842807d398298b14","start_time":null,"end_time":null,"data":{},"created_at":"2025-11-27T20:37:29.047588","updated_at":"2025-11-27T20:37:29.603047"}...
# Successfully started 6 bots

# %% [markdown]
# add_metrics
#
# - time between statuses. Available from meetings

# %%
# new_users = test_suite.add_users(4)
# new_bots = test_suite.add_bots(MEETING_URLS, "Plus4")
# test_suite.start_new_bots(new_bots)

# %%
pd.options.display.max_columns = None
df = test_suite.get_latest_dataframe()
df[['bot_id','platform','meeting_status','segments_count','detected_languages','active_to_first_transcript','transcription_latency']]
# Out:
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'eoBb9qc8goPwPOwDrqFlz3hnuNVkutmte0tgcFwN'}
# DEBUG: Params: None
# DEBUG: JSON data: None
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 's9oqulGOMMnfWI6ELOPQidFL5tiR6sTBWUfqcaAq'}
# DEBUG: Params: None
# DEBUG: JSON data: None
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'vFeLut5sziEy48On8MBFRtY7AxMMIcZRwDHeJs82'}
# DEBUG: Params: None
# DEBUG: JSON data: None
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'FxpBk7SMOv3vIpxTUgvkZIthigtbw4lpWVT0LWyL'}
# DEBUG: Params: None
# DEBUG: JSON data: None
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'Tm4mmqzZex2HUaLP0F9aNGC4b4WkfqLu0T5k696t'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:05 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1912,"user_id":1608,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1912-94cea7c1","start_time":"2025-11-27T20:37:55.938026","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.126253"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/transcripts/google_meet/wmf-qsxs-wgk
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'eoBb9qc8goPwPOwDrqFlz3hnuNVkutmte0tgcFwN'}
# DEBUG: Params: {}
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1915,"user_id":1607,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1915-d6a14f67","start_time":"2025-11-27T20:37:56.959297","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:33.195104"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1913,"user_id":1610,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1913-ae7e8589","start_time":"2025-11-27T20:37:56.061074","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.290111"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/transcripts/google_meet/wmf-qsxs-wgk
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 's9oqulGOMMnfWI6ELOPQidFL5tiR6sTBWUfqcaAq'}
# DEBUG: Params: {}
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1914,"user_id":1611,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1914-216cb157","start_time":"2025-11-27T20:37:56.601814","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.531564"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/transcripts/google_meet/wmf-qsxs-wgk
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'vFeLut5sziEy48On8MBFRtY7AxMMIcZRwDHeJs82'}
# DEBUG: Params: {}
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1916,"user_id":1609,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1916-364cdb78","start_time":"2025-11-27T20:37:56.694764","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.714435"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/transcripts/google_meet/wmf-qsxs-wgk
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'FxpBk7SMOv3vIpxTUgvkZIthigtbw4lpWVT0LWyL'}
# DEBUG: Params: {}
# DEBUG: JSON data: None
#
# DEBUG: Making GET request to http://localhost:18056/transcripts/google_meet/wmf-qsxs-wgk
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'Tm4mmqzZex2HUaLP0F9aNGC4b4WkfqLu0T5k696t'}
# DEBUG: Params: {}
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '26779', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1912,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","start_time":"2025-11-27T20:37:55.938026","end_time":null,"segments":[{"start":0.0,"end":1.92,"text":" So rubber, things like that.","language":"en","created_at":"2025-11-27T20:38:40.082678","speaker":"Google Participant (spaces/PONZzqEwkFcB/devices/566)","absolute_start_time":"2025-11-27T20:37:59.078859+00:00","absolute_end_time":"2025-11-27T2...
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '27982', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1913,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","start_time":"2025-11-27T20:37:56.061074","end_time":null,"segments":[{"start":0.0,"end":2.0,"text":" So rubber, things like that.","language":"en","created_at":"2025-11-27T20:38:40.079550","speaker":"Google Participant (spaces/PONZzqEwkFcB/devices/566)","absolute_start_time":"2025-11-27T20:37:59.207157+00:00","absolute_end_time":"2025-11-27T20...
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '24164', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1915,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","start_time":"2025-11-27T20:37:56.959297","end_time":null,"segments":[{"start":0.0,"end":5.32,"text":" Things like that and also quite a bit of hot gases and in the case of engine number two","language":"en","created_at":"2025-11-27T20:38:40.076814","speaker":"Google Participant (spaces/PONZzqEwkFcB/devices/566)","absolute_start_time":"2025-11-...
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '24259', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1916,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","start_time":"2025-11-27T20:37:56.694764","end_time":null,"segments":[{"start":0.0,"end":5.44,"text":" things like that and also quite a bit of hot gases and in the case of engine number two","language":"en","created_at":"2025-11-27T20:38:40.078754","speaker":"Google Participant (spaces/PONZzqEwkFcB/devices/566)","absolute_start_time":"2025-11-...
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '24711', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1914,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","start_time":"2025-11-27T20:37:56.601814","end_time":null,"segments":[{"start":0.0,"end":1.6,"text":" Rubber, things like that.","language":"en","created_at":"2025-11-27T20:38:40.085727","speaker":"Google Participant (spaces/PONZzqEwkFcB/devices/566)","absolute_start_time":"2025-11-27T20:37:59.746192+00:00","absolute_end_time":"2025-11-27T20:38...
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'eoBb9qc8goPwPOwDrqFlz3hnuNVkutmte0tgcFwN'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1912,"user_id":1608,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1912-94cea7c1","start_time":"2025-11-27T20:37:55.938026","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.126253"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'gLHN6iijs1mu0XdKYTu1HPy2ce6dpXojQ4qOgJWX'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1917,"user_id":1612,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1917-b7793105","start_time":"2025-11-27T20:37:56.669894","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.910570"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/transcripts/google_meet/wmf-qsxs-wgk
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'gLHN6iijs1mu0XdKYTu1HPy2ce6dpXojQ4qOgJWX'}
# DEBUG: Params: {}
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '23713', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1917,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","start_time":"2025-11-27T20:37:56.669894","end_time":null,"segments":[{"start":0.0,"end":5.46,"text":" things like that and also quite a bit of hot gases and in the case of engine number two","language":"en","created_at":"2025-11-27T20:38:40.076010","speaker":"Google Participant (spaces/PONZzqEwkFcB/devices/566)","absolute_start_time":"2025-11-...
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'Tm4mmqzZex2HUaLP0F9aNGC4b4WkfqLu0T5k696t'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:07 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1916,"user_id":1609,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1916-364cdb78","start_time":"2025-11-27T20:37:56.694764","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.714435"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'vFeLut5sziEy48On8MBFRtY7AxMMIcZRwDHeJs82'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:07 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1915,"user_id":1607,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1915-d6a14f67","start_time":"2025-11-27T20:37:56.959297","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:33.195104"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'FxpBk7SMOv3vIpxTUgvkZIthigtbw4lpWVT0LWyL'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:06 GMT, Thu, 27 Nov 2025 20:43:07 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1914,"user_id":1611,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1914-216cb157","start_time":"2025-11-27T20:37:56.601814","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.531564"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 's9oqulGOMMnfWI6ELOPQidFL5tiR6sTBWUfqcaAq'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:07 GMT, Thu, 27 Nov 2025 20:43:07 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1913,"user_id":1610,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1913-ae7e8589","start_time":"2025-11-27T20:37:56.061074","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.290111"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#
# DEBUG: Making GET request to http://localhost:18056/meetings
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'gLHN6iijs1mu0XdKYTu1HPy2ce6dpXojQ4qOgJWX'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 20:43:07 GMT, Thu, 27 Nov 2025 20:43:07 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '721', 'content-type': 'application/json'}
# DEBUG: Response content: {"meetings":[{"id":1917,"user_id":1612,"platform":"google_meet","native_meeting_id":"wmf-qsxs-wgk","constructed_meeting_url":"https://meet.google.com/wmf-qsxs-wgk","status":"active","bot_container_id":"vexa-bot-1917-b7793105","start_time":"2025-11-27T20:37:56.669894","end_time":null,"data":{"status_transition":[{"to":"joining","from":"requested","source":"bot_callback","timestamp":"2025-11-27T20:37:32.910570"},{"to":"awaiting_admission","from":"joining","source":"bot_callback","timestamp":"2025-...
#       bot_id     platform meeting_status  segments_count detected_languages  \
# 0  DemoBot_1  google_meet         active              86               [en]
# 1  DemoBot_2  google_meet         active              77               [en]
# 2  DemoBot_0  google_meet         active              75               [en]
# 3  DemoBot_4  google_meet         active              78               [en]
# 4  DemoBot_3  google_meet         active              90               [en]
# 5  DemoBot_5  google_meet         active              75               [en]
#
#    active_to_first_transcript  transcription_latency
# 0                    3.151956               2.605074
# 1                    3.160044               3.253856
# 2                    3.159948               2.629900
# 3                    3.155679               2.367824
# 4                    3.156890               2.975944
# 5                    3.183464               1.789019

# %%
df[['bot_id','platform','meeting_status','segments_count','detected_languages','active_to_first_transcript','transcription_latency']]
# Out:
#       bot_id     platform meeting_status  segments_count detected_languages  \
# 0  DemoBot_1  google_meet         active              86               [en]
# 1  DemoBot_2  google_meet         active              77               [en]
# 2  DemoBot_0  google_meet         active              75               [en]
# 3  DemoBot_4  google_meet         active              78               [en]
# 4  DemoBot_3  google_meet         active              90               [en]
# 5  DemoBot_5  google_meet         active              75               [en]
#
#    active_to_first_transcript  transcription_latency
# 0                    3.151956               2.605074
# 1                    3.160044               3.253856
# 2                    3.159948               2.629900
# 3                    3.155679               2.367824
# 4                    3.156890               2.975944
# 5                    3.183464               1.789019

# %%
pd.options.display.max_colwidth = None
bot = bots[0]
print(bot.bot_id)
#bot.user_client.get_meetings()
bot.get_transcript_display(tail=3)

# %%
bot.user_client.get_meetings()

# %%
test_suite.cleanup()
